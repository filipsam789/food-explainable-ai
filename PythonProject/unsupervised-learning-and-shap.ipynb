# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import shap
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# # Data preparing

# %%
data = pd.read_csv('./data/data.csv')

# %%
# data['Difference of inflation'] = data['Food Inflation Rate'] - data['Overall Inflation Rate']

# %% [markdown]
# Uncomment this code for encoding with binary encoder

# %%
# binary_encoder = ce.BinaryEncoder(cols=['Item', 'Area'])
# data=binary_encoder.fit_transform(data)

# %%
numerical_columns = ['Food Inflation Rate', 'Raw GDP', 'GDP Growth Rate', 'Item Price Per Tonne',
                     'Overall Inflation Rate', 'Year',
                     ]

# %%
data['Difference of inflation'] = data['Food Inflation Rate'] - data['Overall Inflation Rate']
numerical_columns.append('Difference of inflation')

# %% [markdown]
# Uncomment this code for encoding with label encoder

# %%
label_encoder = LabelEncoder()
data['Item'] = label_encoder.fit_transform(data['Item'])
data['Area'] = label_encoder.fit_transform(data['Area'])
numerical_columns.append('Item')
numerical_columns.append('Area')

# %%
numerical_columns
# Out:
# ['Food Inflation Rate',
#  'Raw GDP',
#  'GDP Growth Rate',
#  'Item Price Per Tonne',
#  'Overall Inflation Rate',
#  'Year',
#  'Difference of inflation',
#  'Item',
#  'Area']

# %%
scaler = RobustScaler()

data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

# %%
data.head()
# Out:
#        Area      Year  Food Inflation Rate   Raw GDP  GDP Growth Rate  \
# 0 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 1 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 2 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 3 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 4 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
#
#        Item  Item Price Per Tonne  Overall Inflation Rate  \
# 0 -1.000000             -0.299190                0.708333
# 1 -0.986667             -0.229156                0.708333
# 2 -0.906667             -0.330420                0.708333
# 3 -0.893333              0.395618                0.708333
# 4 -0.813333             -0.396085                0.708333
#
#    Difference of inflation
# 0                -0.704691
# 1                -0.704691
# 2                -0.704691
# 3                -0.704691
# 4                -0.704691

# %% [markdown]
# # KMeans and dimensionality reduction

# %%
pca = PCA(2)

data_pca = pca.fit_transform(data)
data_pca
# Out:
# array([[ 0.07979987, -1.24697817],
#        [ 0.07617205, -1.24037473],
#        [ 0.08170355, -1.25006348],
#        ...,
#        [-1.02308668,  1.21774295],
#        [-0.62658774,  0.50164457],
#        [-0.53754852,  0.34091324]])

# %%
kmeans = KMeans(2)
kmeans.fit(data_pca)
clusters = kmeans.labels_.tolist()

# %%
label = kmeans.fit_predict(data_pca)

u_labels = np.unique(label)

labels = kmeans.labels_
u_labels
# Out:
# array([0, 1], dtype=int32)

# %% [markdown]
# # Visualization of KMeans clustering

# %%
for i in u_labels:
    plt.scatter(data_pca[label == i , 0] , data_pca[label == i , 1] , label = i)
plt.legend()

# %%
data['label']=labels

# %%
data.head()
# Out:
#        Area      Year  Food Inflation Rate   Raw GDP  GDP Growth Rate  \
# 0 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 1 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 2 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 3 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
# 4 -0.941176 -0.833333             0.160705 -0.422628        -0.784202
#
#        Item  Item Price Per Tonne  Overall Inflation Rate  \
# 0 -1.000000             -0.299190                0.708333
# 1 -0.986667             -0.229156                0.708333
# 2 -0.906667             -0.330420                0.708333
# 3 -0.893333              0.395618                0.708333
# 4 -0.813333             -0.396085                0.708333
#
#    Difference of inflation  label
# 0                -0.704691      1
# 1                -0.704691      1
# 2                -0.704691      1
# 3                -0.704691      1
# 4                -0.704691      1

# %% [markdown]
# # Model training and evaluation

# %%
X, Y = data.drop(columns=['label']), data['label']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
classifier = RandomForestClassifier(
    n_estimators=3,
    max_depth=2,
    max_features='sqrt',
    random_state=42
)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=3, random_state=42)

# %%
y_pred = classifier.predict(x_test)

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       213
#            1       1.00      1.00      1.00      2917
#
#     accuracy                           1.00      3130
#    macro avg       1.00      1.00      1.00      3130
# weighted avg       1.00      1.00      1.00      3130

# %%
data[numerical_columns].head()
# Out:
#    Food Inflation Rate   Raw GDP  GDP Growth Rate  Item Price Per Tonne  \
# 0             0.160705 -0.422628        -0.784202             -0.299190
# 1             0.160705 -0.422628        -0.784202             -0.229156
# 2             0.160705 -0.422628        -0.784202             -0.330420
# 3             0.160705 -0.422628        -0.784202              0.395618
# 4             0.160705 -0.422628        -0.784202             -0.396085
#
#    Overall Inflation Rate      Year  Difference of inflation      Item  \
# 0                0.708333 -0.833333                -0.704691 -1.000000
# 1                0.708333 -0.833333                -0.704691 -0.986667
# 2                0.708333 -0.833333                -0.704691 -0.906667
# 3                0.708333 -0.833333                -0.704691 -0.893333
# 4                0.708333 -0.833333                -0.704691 -0.813333
#
#        Area
# 0 -0.941176
# 1 -0.941176
# 2 -0.941176
# 3 -0.941176
# 4 -0.941176

# %%
data[numerical_columns] = scaler.inverse_transform(data[numerical_columns])

# %%
data.head()
# Out:
#    Area    Year  Food Inflation Rate       Raw GDP  GDP Growth Rate  Item  \
# 0   0.0  2012.0             2.404087  12319.779604        -4.430218   2.0
# 1   0.0  2012.0             2.404087  12319.779604        -4.430218   3.0
# 2   0.0  2012.0             2.404087  12319.779604        -4.430218   9.0
# 3   0.0  2012.0             2.404087  12319.779604        -4.430218  10.0
# 4   0.0  2012.0             2.404087  12319.779604        -4.430218  16.0
#
#    Item Price Per Tonne  Overall Inflation Rate  Difference of inflation  \
# 0                 369.7                     3.2                -0.795913
# 1                 489.9                     3.2                -0.795913
# 2                 316.1                     3.2                -0.795913
# 3                1562.2                     3.2                -0.795913
# 4                 203.4                     3.2                -0.795913
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# Uncomment this code for inverse transform with label encoder

# %%
# data['Area'] = data['Area'].astype(int)
# data['Area'] = label_encoder.inverse_transform(data['Area'])

# %% [markdown]
# Most occurrences of food fraud
# Works with inversed values from label encoder

# %%
# data.groupby(['Area', 'Year'])['label'].sum()

# %%
data.head()
# Out:
#    Area    Year  Food Inflation Rate       Raw GDP  GDP Growth Rate  Item  \
# 0   0.0  2012.0             2.404087  12319.779604        -4.430218   2.0
# 1   0.0  2012.0             2.404087  12319.779604        -4.430218   3.0
# 2   0.0  2012.0             2.404087  12319.779604        -4.430218   9.0
# 3   0.0  2012.0             2.404087  12319.779604        -4.430218  10.0
# 4   0.0  2012.0             2.404087  12319.779604        -4.430218  16.0
#
#    Item Price Per Tonne  Overall Inflation Rate  Difference of inflation  \
# 0                 369.7                     3.2                -0.795913
# 1                 489.9                     3.2                -0.795913
# 2                 316.1                     3.2                -0.795913
# 3                1562.2                     3.2                -0.795913
# 4                 203.4                     3.2                -0.795913
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# # SHAP explainability

# %%
explainer = shap.Explainer(classifier)

shap_values = explainer(x_test)

# %%
shap.summary_plot(shap_values[:, :, 1], x_test, plot_type="bar")

# %%
shap.summary_plot(shap_values[:, :, 1], x_test)

# %%
shap_values_array = shap_values.values
shap.dependence_plot('Overall Inflation Rate', shap_values_array[:, :, 1], x_test, interaction_index='Food Inflation Rate')

# %%
shap.initjs()
shap.plots.force(explainer.expected_value[1], shap_values_array[:, :, 1], x_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# /Users/filipsamardziski/venv/lib/python3.10/site-packages/shap/plots/_force.py:208: UserWarning: shap.plots.force is slow for many thousands of rows, try subsampling your data.
#   warnings.warn("shap.plots.force is slow for many thousands of rows, try subsampling your data.")
# <div id='iS16A6Y1RYNHJ1779WGPX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.9253934020289161, "link": "identity", "featureNames": ["Area", "Year", "Food Inflation Rate", "Raw GDP", "GDP Growth Rate", "Item", "Item Price Per Tonne", "Overall Inflation Rate", "Difference of inflation"], "explanations": [{"outValue": 1.0, "simIndex": 1170.0, "features": {"0": {"effect": 0.0, "value": 0.47058823529411764}, "1": {"effect": 0.0, "value": 0.5}, "2": {"effect": 0.05229583937116258, "value": 1.0167587316485542}, "3": {"effect": 0.0, "value": 0.07664111359873568}, "4": {"effect": -6.214943529737238e-05, "value": -0.28450846464946794}, "5": {"effect": 0.0, "value": -0.9066666666666666}, "6": {"effect": 0.0, "value": -0.3924139136514595}, "7": {"effect": 0.02237290803521876, "value": 0.33333333333333326}, "8": {"effect": 0.0, "value": 1.1464097624787173}}}, {"outValue": 1.0, "simIndex": 1171.0, "features": {"0": {"effect": 0.0, "value": 0.17647058823529413}, "1": {"effect": 0.0, "value": 0.6666666666666666}, "2": {"effect": 0.05229583937116258, "value": 0.4172628262106012}, "3": {"effect": 0.0, "value": -0.4191183298294759}, "4": {"effect": -6.214943529737